-- %%
select 
  a.rank,
  a.artist, 
  a.title,
  a.region,
  a.spotify_uri,
  b.dominant_emotion,
  b.emotion_love, b.emotion_longing, b.emotion_joy, b.emotion_heartbreak, b.emotion_grief, b.emotion_despair,b.emotion_hope,
  b.emotion_lonely, b.emotion_sensual, b.emotion_anger
from songs_db.default.top_titles a
left join songs_db.default.emotion_scores b
on a.spotify_uri = b.spotify_uri
-- where b.dominant_emotion is null
;

-- select * from songs_db.default.top_titles;
