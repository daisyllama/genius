# %%
import pandas as pd

file_path = "/Users/wednesday/Documents/GitHub/lyrics_analysis/data/processed/lyrics/2026/03/05/lyrics.csv"

df = pd.read_csv(file_path)

print(df.head())
# Out:
#    rank                            artist                    title    region  \
# 0     1        Mr Plata, El Americano 4KT           Las Muñequitas  Colombia
# 1     2            ARIA VEGA, Ryan Castro  CHÉVERE (premium_remix)  Colombia
# 2     3        Ryan Castro, Kapo, Gangsta                 LA VILLA  Colombia
# 3     4                           Kris R.                    GANAS  Colombia
# 4     5  W Sound, Beéle, Ovy On The Drums    La Plena - W Sound 05  Colombia
#
#               spotify_uri                                             lyrics
# 0  4nJJCRYru4QQakCiUA155f  (Dímelo, ¿me vas a dar lo que yo pido?)\nDame ...
# 1  3CBEVPwR3kUXDoTx1lqFUQ  ARIA VEGA, Ryan Castro\nLa costeñita premium y...
# 2  2ZyrAym0sRLwt4PhGotHuI  Kapo, Ryan Castro, Gangsta\nQué chimba, SOG\nT...
# 3  4KE9Ne3hgh18B3Th4xcylg  Yeah, yeah\nYeah, yeah\n\nMi amor, culeemos co...
# 4  6iOndD4OFo7GkaDypWQIou  O-O-Ovy On The Drums\nYou're the apple of my e...

# %%
missing_lyrics = df[df['lyrics'].isnull()]

display(missing_lyrics)
# Out:
#      rank                                             artist  \
# 36     37                       Yeison Jimenez, Chayín Rubio
# 40     41             Luister La Voz, maikol el insoportable
# 48     49     El Bogueto, Anuel AA, Fuerza Regida, Yung Beef
# 83     84                       Kris R., GeezyDee, Prodmonja
# 93     94  Yeison Maje, Ciro Quiñonez, Luis Alfonso, Yeis...
# ..    ...                                                ...
# 645   175                            Ronghao Li, A-Mei Chang
# 646   176                                              aespa
# 647   177                                       Amazing Show
# 657   188                                       icyball 冰球樂團
# 668   200                                                马师傅
#
#                               title    region             spotify_uri lyrics
# 36                 El Mejor - Remix  Colombia  1xRRW5ZrL7I9EG8CGZrXHE    NaN
# 40                            Ozono  Colombia  4acvrfbXrDPFQNNDnFZnpC    NaN
# ...
